# %% [markdown]
# #### API Testing Notebook

# %%
from NGDataPortal import Wrapper

# %%
stream = 'embedded-wind-and-solar-forecasts'
wrapper = Wrapper(stream)

df = wrapper.query_API()

df.head()
# Out:
#    _id             DATE_GMT TIME_GMT      SETTLEMENT_DATE  SETTLEMENT_PERIOD  \
# 0    1  2024-08-11T00:00:00    12:30  2024-08-11T00:00:00                 27
# 1    2  2024-08-11T00:00:00    13:00  2024-08-11T00:00:00                 28
# 2    3  2024-08-11T00:00:00    13:30  2024-08-11T00:00:00                 29
# 3    4  2024-08-11T00:00:00    14:00  2024-08-11T00:00:00                 30
# 4    5  2024-08-11T00:00:00    14:30  2024-08-11T00:00:00                 31
#
#    EMBEDDED_WIND_FORECAST  EMBEDDED_WIND_CAPACITY  EMBEDDED_SOLAR_FORECAST  \
# 0                     845                    6563                     9615
# 1                     903                    6563                     9387
# 2                     971                    6563                     9050
# 3                    1039                    6563                     8594
# 4                    1125                    6563                     7991
#
#    EMBEDDED_SOLAR_CAPACITY
# 0                    16396
# 1                    16396
# 2                    16396
# 3                    16396
# 4                    16396
